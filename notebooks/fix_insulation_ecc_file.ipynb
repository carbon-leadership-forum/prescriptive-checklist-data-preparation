# %%
import ftfy
import pandas as pd
from pathlib import Path

# %%
current_file_path = Path(__vsc_ipynb_file__)
main_directory = current_file_path.parents[1]
df = pd.read_csv(main_directory / "references/baseline_material_insulation_ecc.csv")
df["insulation_types"] = df["insulation_types"].apply(ftfy.fix_text)
df.to_csv(main_directory / "references/baseline_material_insulation_ecc.csv", index=False, encoding="utf-8")
